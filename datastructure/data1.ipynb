# %%
l=[22,23,44,55,7.7,'hello']
l
# Out:
# [22, 23, 44, 55, 7.7, 'hello']

# %%
#indexing and slicing in list
l[4]
l[5]
# Out:
# 'hello'

# %%
l[1:4]
# Out:
# [23, 44, 55]

# %%
s1='hello'
s1[0:2]
# Out:
# 'he'

# %%
l.append(100)

# %%
l
# Out:
# [22, 23, 44, 55, 7.7, 'hello', 100, 100, 100, 100]

# %%
l.insert(3,80)

# %%
l
# Out:
# [22, 80, 23, 80, 44, 55, 7.7, 'hello', 100, 100, 100, 100]
