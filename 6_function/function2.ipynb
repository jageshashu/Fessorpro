# %%
stock_prices={'tsla':900,'aapl':150,'msft':300,'goog':2800,'nvda':220}

def print_stock_prices(stock_prices:dict)->int:
    total_prices=0
    for i,j in stock_prices.items():
        print(i,j)
        total_prices+=j
    return total_prices
a=print_stock_prices(stock_prices)
print(a)
# Out:
# tsla 900
# aapl 150
# msft 300
# goog 2800
# nvda 220
# 4370
