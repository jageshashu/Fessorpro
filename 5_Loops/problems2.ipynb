# %%
stock_prices={'AAPL': 150, 'GOOG': 2800, 'MSFT': 300, 'AMZN': 3500, 'TSLA': 700}
print(stock_prices)
portfolio=[]
while True:

    name=input('Enter stock name: (press q to quit) ').upper()

    if name=='Q':
        break

    price=stock_prices.get(name)

    if price is None:
        print('Stock not found. Please try again.')
    else:
        print(f'stock {name} is added to portfolio')
        portfolio.append(name)
print('portfolio',portfolio)
# Out:
# {'AAPL': 150, 'GOOG': 2800, 'MSFT': 300, 'AMZN': 3500, 'TSLA': 700}
# stock TSLA is added to portfolio
# stock GOOG is added to portfolio
# portfolio ['TSLA', 'GOOG']

# %%
# Reverse the list using loop, while loop or both

l1=[22,33,44,55,66]
# l1.reverse()
l1
# Out:
# [22, 33, 44, 55, 66]

# %%
list(range(len(l1)-1,-1,-1))      #range(len()-1,-1,-1)
# Out:
# [4, 3, 2, 1, 0]

# %%
rev=[]
for i in range(len(l1)-1,-1,-1):
    rev.append(l1[i])
rev
# Out:
# [66, 55, 44, 33, 22]

# %%
# Type 3
 
 
s1='hello'
r1=''
for i in range(len(s1)-1,-1,-1):
    r1=r1+s1[i]
r1
# Out:
# 'olleh'

# %%
# Type 1

r2=''
for i in s1:
    r2=i+r2
    print(r2)
r2
# Out:
# h
# eh
# leh
# lleh
# olleh
# 'olleh'

# %%
# problem - count that how many times a character o is present in a string.

sentence="python is fun to learn"
char='o'
count=0
for i in sentence:
    if i==char:
        count=count+1
count
# Out:
# 2
