# %%
foreign_exchange = {
    "base_currency": "USD",
    "exchange_rates": 
    {
        "EUR": {
            "current_rate": 0.85,
            "historical_rates": 
            [
               {"date": "2024-01-10", "rate":  0.84},
                {"date": "2024-01-09", "rate": 0.85}
            ]
        },
        "JPY": {
            "current_rate": 110.0,
            "historical_rates": 
            [
                {"date": "2024-01-10", "rate": 109.5},
                {"date": "2024-01-09", "rate": 110.20}
            ]
        }
    }
}
foreign_exchange
# Out:
# {'base_currency': 'USD',
#  'exchange_rates': {'EUR': {'current_rate': 0.85,
#    'historical_rates': [{'date': '2024-01-10', 'rate': 0.84},
#     {'date': '2024-01-09', 'rate': 0.85}]},
#   'JPY': {'current_rate': 110.0,
#    'historical_rates': [{'date': '2024-01-10', 'rate': 109.5},
#     {'date': '2024-01-09', 'rate': 110.2}]}}}

# %%
foreign_exchange.get('exchange_rates').get('JPY').get('current_rate')
# Out:
# 110.0

# %% [markdown]
# List Of LIst

# %%
l1=[11,2,[54,64,74,84],333,44,[45,67,87,90,[65,75,85,95]]]
l1
# Out:
# [11, 2, [54, 64, 74, 84], 333, 44, [45, 67, 87, 90, [65, 75, 85, 95]]]

# %%
l1[2][-1]
# Out:
# 84

# %%
l1[-1][-1][0]
# Out:
# 65

# %% [markdown]
# # Dictionary of Dictionary

# %%
d1={'tech':{'tcs':{'revenue':1000,'profit':100},
            'infosys':{'revenue':2000,'profit':200},
            'infy':{'revenue':3000,'profit':300}
            },
    'fmcg':{'hindustan_unilever':{'revenue':1000,'profit':100},
             'nestle':{'revenue':2000,'profit':200},
             'dabur':{'revenue':1500,'profit':150}
            },
     'bank': {'hdfc':{'revenue':1000,'profit':100},
              'icici':{'revenue':2000,'profit':200},
              'sbi':{'revenue':3000,'profit':300}
            }   
}

# %%
d1.get('fmcg').get('dabur').get('profit')
# Out:
# 150

# %% [markdown]
# List of Dictionary

# %%
d1={'tech':{'tcs':[300,200,100,300],
            'infosys':[400,300,200,100],
            'infy':[500,400,300,200]
            },
    'fmcg':{'hindustan_unilever':[100,200,300,400],
             'nestle':[200,300,400,500],
             'dabur':[150,250,350,450]
            },
     'bank': {'hdfc':[1000,100],
              'icici':[2000,200],
              'sbi':[3000,300]
            }   
}

# %%
d1.get('fmcg').get('dabur')[-1]

# %% [markdown]
# Dictionary of List

# %%
dl1=[
    {'tech':{'tcs':[300,200,100,300]}},
    {'fmcg':{'hindustan_unilever':[100,200,300,400]}},
    {'bank': {'hdfc':[1000,100]}}
]

# %%
dl1[1].get('fmcg')

# %%
hedge_fund_portfolio = {
    "fund_name": "Alpha Investments",
    "portfolio_value": 50000000,
    "investments": [

        {
            "type": "Equity",
            "holdings": [
                {"ticker": "AAPL", "quantity": 10000, "average_buy_price": 120},
                {"ticker": "TSLA", "quantity": 5000, "average_buy_price": 600}
            ]
        },

        {
            "type": "Fixed Income",
            "holdings": [
                {"bond_issue": "US Treasuries", "amount": 10000000, "yield": 1.5}
            ]
        },

        {
            "type": "Derivatives",
            "holdings": [
                {"instrument": "Options", "details": {"underlying": "GOOGL", "type": "Call", "strike_price": 1500}}
            ]
        }
    ],

    "performance_metrics": {
        "year_to_date_return": 5.2,
        "five_year_annualized_return": 7.1
    }
}

# %%
hedge_fund_portfolio.get("investments")[2].get("strike_price")[-1]
